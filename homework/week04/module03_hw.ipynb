# %% [markdown]
# # GEOG 592 — Module 3 Homework, Pandas Intro
# Hailey Rodriguez

# %% [markdown]
# Using the cleaned CSV file from the previous homework, create a Jupyter Notebook that opens and explores the data using pandas.
#
# Use the following methods:
#
# df.head()
#
# df.shape
#
# df.columns
#
# df.dtypes
#
# df.info()
#
# Also use a mask to create a dataframe with less rows.
#
# Upload the JN to homework/week04
#
# Input the link of your GitHub JN in Canvas. Do not use AI for this HW.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ### Read a CSV into a DataFrame

# %%
filename = "scdnr_species_county_clean.csv"
df = pd.read_csv(filename)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.head()
# Out:
#    record_id     county         scientific_name        s_common_name  \
# 0          1  Abbeville    Alasmidonta varicosa        Brook Floater
# 1          2  Abbeville       Ameiurus brunneus       Snail Bullhead
# 2         16  Abbeville          Ameiurus catus        White Catfish
# 3         31  Abbeville  Ameiurus platycephalus        Flat Bullhead
# 4         79  Abbeville   Ammodramus savannarum  Grasshopper Sparrow
#
#                                            inf_taxon group_member_type_desc  \
# 0                                 Freshwater Mussels             Zoological
# 1  Fishes - Freshwater and Anadromous Bony, Carti...             Zoological
# 2  Fishes - Freshwater and Anadromous Bony, Carti...             Zoological
# 3  Fishes - Freshwater and Anadromous Bony, Carti...             Zoological
# 4                                              Birds             Zoological
#
#   g_rank s_rank  g1g2s1s2    state_status  ... swap_priority_desc  \
# ...

# %%
df.shape
# Out:
# (6743, 25)

# %%
df.columns
# Out:
# Index(['record_id', 'county', 'scientific_name', 's_common_name', 'inf_taxon',
#        'group_member_type_desc', 'g_rank', 's_rank', 'g1g2s1s2',
#        'state_status', 'state_protect_status_desc', 'fed_status',
#        'fed_protect_desc', 'listed_species', 'tracked_species',
#        'swap_priority_desc', 'presence_status', 'obsrank', 'locuseclass',
#        'date_class', 'first_obs_date', 'last_survey_date', 'dateconvert',
#        'count_records', 'eo_id_sc'],
#       dtype='str')

# %%
df.dtypes
# Out:
# record_id                    int64
# county                         str
# scientific_name                str
# s_common_name                  str
# inf_taxon                      str
# group_member_type_desc         str
# g_rank                         str
# s_rank                         str
# g1g2s1s2                     int64
# state_status                   str
# state_protect_status_desc      str
# fed_status                     str
# fed_protect_desc               str
# listed_species               int64
# tracked_species              int64
# swap_priority_desc             str
# presence_status              int64
# obsrank                        str
# locuseclass                    str
# date_class                     str
# first_obs_date                 str
# last_survey_date               str
# dateconvert                    str
# count_records                int64
# eo_id_sc                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6743 entries, 0 to 6742
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   record_id                  6743 non-null   int64
#  1   county                     6743 non-null   str
#  2   scientific_name            6743 non-null   str
#  3   s_common_name              6743 non-null   str
#  4   inf_taxon                  6743 non-null   str
#  5   group_member_type_desc     6743 non-null   str
#  6   g_rank                     6743 non-null   str
#  7   s_rank                     6743 non-null   str
#  8   g1g2s1s2                   6743 non-null   int64
#  9   state_status               6743 non-null   str
#  10  state_protect_status_desc  6743 non-null   str
#  11  fed_status                 6743 non-null   str
#  12  fed_protect_desc           6743 non-null   str
#  13  listed_species             6743 non-null   int64
# ...

# %%
mask = df['county'].str.startswith('A', na=False)
df2 =df[mask]
df2
# Out:
#      record_id     county         scientific_name              s_common_name  \
# 0            1  Abbeville    Alasmidonta varicosa              Brook Floater
# 1            2  Abbeville       Ameiurus brunneus             Snail Bullhead
# 2           16  Abbeville          Ameiurus catus              White Catfish
# 3           31  Abbeville  Ameiurus platycephalus              Flat Bullhead
# 4           79  Abbeville   Ammodramus savannarum        Grasshopper Sparrow
# ..         ...        ...                     ...                        ...
# 541       4967   Anderson      Terrapene carolina         Eastern Box Turtle
# 542       4970   Anderson        Trillium rugelii  Southern Nodding Trillium
# 543       4971   Anderson               Tyto alba                   Barn Owl
# 544       4974   Anderson        Viola tripartita        Three-parted Violet
# 545       4979   Anderson        Waterbird Colony           Waterbird Colony
#
# ...
